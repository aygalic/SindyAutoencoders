# %% [markdown]
# # Thomas attractor
#
# The Thomas attractor. See :meth:`deeptime.data.thomas_attractor`.

# %%
# %matplotlib widget

import deeptime
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Line3DCollection

system = deeptime.data.thomas_attractor(.1)

x0 = np.random.uniform(-3, 3, size=(50, 3))
traj = system.trajectory(x0, 500)
tstart = 0
tfinish = system.h * system.n_steps * len(traj)

ax = plt.figure().add_subplot(projection='3d')

for t in traj:
    points = t.reshape((-1, 1, 3))
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    coll = Line3DCollection(segments, cmap='twilight', alpha=.3)
    coll.set_array(t[:, -1])
    coll.set_linewidth(1)
    ax.add_collection(coll)

ax.plot(*traj[0].T, alpha=0)
ax.set_box_aspect(np.ptp(traj[0], axis=0))
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(x0)
# Out:
# [[-0.68811819  1.11835397  1.94435388]
#  [ 0.29934413 -2.94026566 -2.02938014]
#  [ 1.23353254  2.57486184 -0.18484998]
#  [-2.80605459 -1.36747818 -2.1308126 ]
#  [ 1.8293777  -0.14284549 -1.46647533]
#  [ 1.66978471 -2.88661181 -2.03535552]
#  [-2.56419468  1.70118054 -2.34431863]
#  [ 1.64578975 -0.77607708  0.59244778]
#  [-0.07074086 -0.3166871   2.9469183 ]
#  [ 0.77131001  0.37677527  1.68135869]
#  [ 2.79364566 -2.58926018 -0.08387557]
#  [-0.23899398 -0.10189262  2.82562025]
#  [ 2.26311295  1.92456742  2.71132793]
#  [ 2.13870805 -2.92029449  0.74720991]
#  [-1.33200773  0.88272637 -2.62328319]
#  [-1.60139079 -1.31685421 -1.01480344]
#  [-2.66430213  1.69713546 -0.4366915 ]
#  [-1.71839691  2.9790918   1.67930689]
#  [-2.83615668 -1.97883159  0.86038421]
#  [ 1.91833462  2.88756406  2.65561439]
#  [-0.77311992  0.0959462   2.78763583]
#  [-0.84810931  1.17794029 -1.35013388]
#  [-2.76032329  0.2977115  -0.05181581]
#  [-0.07024169 -0.07892957  0.12845503]
#  [-1.55702131  1.37856363 -2.62592627]
#  [-1.72485893 -0.34210926  0.54094371]
#  [-1.6357825  -2.19476536 -1.98373806]
#  [ 2.06643903  1.99298673 -2.52285519]
#  [ 2.26221198  1.43337833  0.82377867]
#  [ 0.88292133 -2.58638465  2.90723099]
#  [-1.47772652 -1.79775886 -0.68069653]
#  [-1.28011551 -2.01604879  0.39263986]
#  [ 0.44387668 -0.78726492  1.99665415]
#  [ 1.5946262  -0.68077377 -2.79283768]
#  [ 1.45100401 -1.83942614 -1.60056399]
#  [-1.73685929 -1.85009184  2.26880138]
#  [ 2.558282   -1.14291381  2.85384982]
#  [ 0.6630344  -0.76071722  0.21346234]
#  [-2.55462799  0.1866855  -1.92756609]
#  [ 1.30063044 -0.05256682  0.56982011]
#  [ 1.00973972 -2.28088023 -2.43588854]
#  [-1.90462338  0.85690619  2.72285894]
#  [ 2.47023914 -1.8045096  -2.29690083]
#  [ 2.76195461  2.47710541  0.70260631]
#  [ 2.79154852  0.72027545  0.3405515 ]
#  [-2.02729012 -2.75684934  0.95684897]
#  [ 2.81213196 -0.41535001  2.07829873]
#  [-2.9391094  -1.13948445 -2.67259311]
#  [-0.37281888 -0.30932314  1.81880177]
#  [ 1.47526329 -0.5667436   0.37725995]]
